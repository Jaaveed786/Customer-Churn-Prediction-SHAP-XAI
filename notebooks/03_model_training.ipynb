# %% [markdown]
# # 03. Model Training & Comparison
#
# **Objective:** Train Logistic Regression and Random Forest models on preprocessed features, tune business threshold, and compare performance.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('../src').resolve()))

from train import train
# Run full training pipeline
train()
