# %% [markdown]
# # 04. SHAP Explainability
#
# **Objective:** Compute global and local SHAP explanations using TreeExplainer and LinearExplainer.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('../src').resolve()))

from generate_shap_plots import generate_all
generate_all()
